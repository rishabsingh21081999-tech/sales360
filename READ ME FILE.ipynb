# %% [markdown]
# #SalesAnalysis360/
# │
# ├── data/
# │   ├── Customer_Master.csv
# │   ├── Product_Master.csv
# │   ├── Store_Master.csv
# │   ├── Orders.csv
# │   ├── Returns.csv
# │
# ├── notebooks/
# │   ├── Data_Cleaning.ipynb
# │   ├── Data_Merging.ipynb
# │   ├── EDA_Report_Notebook.ipynb
# │
# ├── reports/
# │   ├── EDA_Report_Only.pdf
# │   ├── SalesAnalysis360_Final_Report.pdf
# │
# ├── presentation/
# │   ├── SalesAnalysis360_Presentation.pptx
# │
# └── README.md
